# %% [markdown]
# # Assignment 3 Report

# %% [markdown]
# Xinya Bi 6195350
#
# Xu Wang 6235379
#
# C. E. Felix Aires 4325893

# %% [markdown]
# ## RANSAC Method

# %% [markdown]
# ## Region Growing Method
#
# ## Hough Transformation
